# %%
import selenium
from selenium import webdriver

# %%
import pandas as pd
import time

# %% [markdown]
# Q1. Write a python program which searches all the product under a particular product vertical from www.amazon.in. The product verticals to be searched will be taken as input from user. For e.g. If user input is ‘guitar’. Then search for guitars.

# %%
#Locating Chrome driver for automation
driver = webdriver.Chrome('D:/Installed Software  2/chromedriver.exe')

#calling web page URL of amazon
page_url = 'https://www.amazon.in/'
driver.get(page_url)
# Out:
# <ipython-input-3-fc375300b516>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('D:/Installed Software  2/chromedriver.exe')

# %%
search_item = input("Enter search item - ")                                    #user input
search = driver.find_element_by_xpath("//div[@class = 'nav-fill']/div/input")  #access search bar 
search.send_keys(search_item)                                                  #send values to search bar

time.sleep(1)
search_btn = driver.find_element_by_xpath("//div[@class = 'nav-search-submit nav-sprite']/span/input")  #Button access
search_btn.click()                                                                                      #click button
# Out:
# Enter search item - Guitar
# <ipython-input-6-96e95dddab56>:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search = driver.find_element_by_xpath("//div[@class = 'nav-fill']/div/input")  #access search bar
# <ipython-input-6-96e95dddab56>:6: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_btn = driver.find_element_by_xpath("//div[@class = 'nav-search-submit nav-sprite']/span/input")  #Button access

# %% [markdown]
# Q2 In the above question, now scrape the following details of each product listed in first 3 pagesof your search results and save it in a data frame and csv. In case if any product vertical has less than 3 pages in search results then scrape all the products available under that product vertical. Details to be scraped are: "Brand Name", "Name of the Product", "Rating", "No. of Ratings", "Price", "Return/Exchange", "Expected Delivery", "Availability", "Other Details" and “Product URL”. In case, if any of the details are missing for any of the product then replace it by “-“.

# %%
# scrape all product urls
product_urls = []
start=0
end=3
for page in range(start,end):#for loop for scrapping 3 page
    url=driver.find_elements_by_xpath('//a[@class="a-link-normal a-text-normal"]')       #scraping urls
    for i in url:
        product_urls.append(i.get_attribute("href"))                        #appending the urls in product_urls list
    nxt_button=driver.find_element_by_xpath("//li[@class='a-normal'][1]/a")     #scraping the list of buttons from the page
    nxt_button.click()
    time.sleep(2)

#Make empty lists
Brand = []   
Name = []
Rating = []
no_of_ratings = []
Price = []
Return = []
expected_delivery = []
Availability = [] 
Other_Details = []

for url in product_urls:
    driver.get(url)
    time.sleep(2)
    
    # Extracting Brand from xpath
    try:
        brand = driver.find_element_by_xpath('//a[@id="bylineInfo"]')      
        Brand.append(brand.text)
    except NoSuchElementException:
        Brand.append('-')    


    time.sleep(1)
    # Extracting name from id
    try:
        name = driver.find_element_by_id('productTitle')      
        Name.append(name.text)
    except NoSuchElementException:
        Name.append('-')


    time.sleep(1)    
    # Extracting Ratings from xpath    
    try:
        rating = driver.find_element_by_xpath('//span[@class="a-size-base a-nowrap"]//span')  
        Rating.append(rating.text)
    except NoSuchElementException:
        Rating.append('-')


    time.sleep(1)
    # Extracting No of Ratings from xpath
    try:
        no_rating = driver.find_element_by_id('acrCustomerReviewText')  
        no_of_ratings.append(no_rating.text)
    except NoSuchElementException:
        no_of_ratings.append('-')


    time.sleep(1)
    # Extracting price from xpath    
    try:
        price = driver.find_element_by_xpath('//td[@class="a-span12"]')  
        Price.append(price.text)
    except NoSuchElementException:
        Price.append('-')


    time.sleep(1)
    # Extracting Return from xpath
    try:
        return_ = driver.find_element_by_xpath('//a[@class="a-size-small a-link-normal a-text-normal"]')  
        Return.append(return_.text)
    except NoSuchElementException:
        Return.append('-')


    time.sleep(1)
    # Extracting expected_delivery from xpath
    try:
        exptd_dlvry= driver.find_element_by_xpath('//span[@class="a-color-error"]')  
        expected_delivery.append(exptd_dlvry.text)
    except NoSuchElementException:
         expected_delivery.append('-')


    time.sleep(1)
    # Extracting Availability from xpath         
    try:
        avl= driver.find_element_by_xpath('//span[@class="a-size-medium a-color-success"]')  
        Availability.append(avl.text)
    except NoSuchElementException:
        Availability.append('-')



    time.sleep(1)
    # Extracting Other Details from xpath    
    try:
        othr_dtls= driver.find_element_by_xpath('//ul[@class="a-unordered-list a-vertical a-spacing-mini"]')  
        Other_Details.append(othr_dtls.text)
    except NoSuchElementException:
        Other_Details.append('-')

time.sleep(2)    
# Make dataframe
prod_df = pd.DataFrame({'Brand':Brand,'Name':Name,'Rating':Rating,'No. of ratings':no_of_ratings,'Price':Price,
                        'Return/Exchange':Return,'Expected Delivery':expected_delivery,'Availability':Availability,
                        'Other Details':Other_Details,'URL':product_urls})
prod_df.head(5)
# Out:
# <ipython-input-7-c1318ef53284>:6: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   url=driver.find_elements_by_xpath('//a[@class="a-link-normal a-text-normal"]')       #scraping urls
# <ipython-input-7-c1318ef53284>:9: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   nxt_button=driver.find_element_by_xpath("//li[@class='a-normal'][1]/a")     #scraping the list of buttons from the page
# <ipython-input-7-c1318ef53284>:30: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   brand = driver.find_element_by_xpath('//a[@id="bylineInfo"]')
# <ipython-input-7-c1318ef53284>:39: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   name = driver.find_element_by_id('productTitle')
# <ipython-input-7-c1318ef53284>:48: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   rating = driver.find_element_by_xpath('//span[@class="a-size-base a-nowrap"]//span')
# <ipython-input-7-c1318ef53284>:57: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   no_rating = driver.find_element_by_id('acrCustomerReviewText')
# <ipython-input-7-c1318ef53284>:66: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   price = driver.find_element_by_xpath('//td[@class="a-span12"]')
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-7-c1318ef53284> in <module>
#      65     try:
# ---> 66         price = driver.find_element_by_xpath('//td[@class="a-span12"]')
#      67         Price.append(price.text)
#
# D:\Installed Software\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     513         )
# --> 514         return self.find_element(by=By.XPATH, value=xpath)
#     515
#
# D:\Installed Software\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#    1237
# -> 1238         return self.execute(Command.FIND_ELEMENT, {
#    1239             'using': by,
#
# D:\Installed Software\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     417         if response:
# --> 418             self.error_handler.check_response(response)
#     419             response['value'] = self._unwrap_value(
#
# D:\Installed Software\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     242             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 243         raise exception_class(message, screen, stacktrace)
#     244
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//td[@class="a-span12"]"}
#   (Session info: chrome=96.0.4664.110)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x003D06F3+2492147]
# 	Ordinal0 [0x00369BD1+2071505]
# 	Ordinal0 [0x00272478+1057912]
# 	Ordinal0 [0x0029C964+1231204]
# 	Ordinal0 [0x002C6B62+1403746]
# 	Ordinal0 [0x002B57FA+1333242]
# 	Ordinal0 [0x002C4F38+1396536]
# 	Ordinal0 [0x002B568B+1332875]
# 	Ordinal0 [0x002921D4+1188308]
# 	Ordinal0 [0x0029302F+1191983]
# 	GetHandleVerifier [0x005567A6+1545030]
# 	GetHandleVerifier [0x0060105C+2243580]
# 	GetHandleVerifier [0x0045BC97+518199]
# 	GetHandleVerifier [0x0045AD80+514336]
# 	Ordinal0 [0x0036ED2D+2092333]
# 	Ordinal0 [0x00372EE8+2109160]
# 	Ordinal0 [0x00373022+2109474]
# 	Ordinal0 [0x0037CB71+2149233]
# 	BaseThreadInitThunk [0x77B2FA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x77E67A9E+286]
# 	RtlGetAppContainerNamedObjectPath [0x77E67A6E+238]
#
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-c1318ef53284> in <module>
#      66         price = driver.find_element_by_xpath('//td[@class="a-span12"]')
#      67         Price.append(price.text)
# ---> 68     except NoSuchElementException:
#      69         Price.append('-')
#      70
#
# NameError: name 'NoSuchElementException' is not defined

# %% [markdown]
# Q3. Write a python program to access the search bar and search button on images.google.com and scrape 100 images each for keywords ‘fruits’, ‘cars’ and ‘Machine Learning’.

# %%
#Importing requests
import requests
import time

#Locating Chrome driver for automation
driver = webdriver.Chrome('D:/Installed Software  2/chromedriver.exe')
time.sleep(3)

# Opening URL
url = "https://images.google.com/"
driver.get(url)

item = input("Enter search item - ")
search = driver.find_element_by_xpath('//*[@id="sbtc"]/div/div[2]/input')    # Access search bar
search.send_keys(item)       # Input item to search bar
search_btn = driver.find_element_by_xpath('//*[@id="sbtc"]/button')    # Access search button
search_btn.click()        # Clicking the search button


# 500 time we scroll down by 10000 in order to generate more images on the website
for _ in range(500):
    driver.execute_script("window.scrollBy(0,10000)")
    
img = driver.find_elements_by_xpath('//img[@class="rg_i Q4LuWd"]')

img_urls = []
img_data = []
for image in img:
    source= image.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            img_urls.append(source)
            
            
for i in range(len(img_urls)):
    if i >= 100:
        break
   
    response= requests.get(img_urls[i])
    file = open(r"D:\Scraping Images\pics"+str(i)+".jpg", "wb")
    file.write(response.content)
print("Images Downloaded")
# Out:
# <ipython-input-8-d8068e3aaba9>:6: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('D:/Installed Software  2/chromedriver.exe')
# Enter search item - CAR
# <ipython-input-8-d8068e3aaba9>:14: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search = driver.find_element_by_xpath('//*[@id="sbtc"]/div/div[2]/input')    # Access search bar
# <ipython-input-8-d8068e3aaba9>:16: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_btn = driver.find_element_by_xpath('//*[@id="sbtc"]/button')    # Access search button
# <ipython-input-8-d8068e3aaba9>:24: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   img = driver.find_elements_by_xpath('//img[@class="rg_i Q4LuWd"]')
# Images Downloaded

# %% [markdown]
# Q4. Write a python program to search for a smartphone(e.g.: Oneplus Nord, pixel 4A, etc.) on www.flipkart.com and scrape following details for all the search results displayed on 1st page. Details to be scraped: “Brand Name”, “Smartphone name”, “Colour”, “RAM”, “Storage(ROM)”, “Primary Camera”, “Secondary Camera”, “Display Size”, “Display Resolution”, “Processor”, “Processor Cores”, “Battery Capacity”, “Price”, “Product URL”. Incase if any of the details is missing then replace it by “- “. Save your results in a dataframe and CSV.

# %%
# Activating the chrome browser
from selenium.webdriver.chrome.service import Service
s = Service("D:/Installed Software  2/chromedriver.exe")
driver = webdriver.Chrome(service = s)
time.sleep(3)

# opning flipkart.com
driver.get('https://www.flipkart.com/')
time.sleep(3)
try:
    login_X_button = driver.find_element_by_xpath('//button[@class="_2KpZ6l _2doB4z"]')                      # Button to close login popup
    login_X_button.click()
except NoSuchElementException : 
    print("No Login page")
    
search_bar = driver.find_element_by_xpath('//*[@id="container"]/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input')    # Finding the search bar using it's xpath
search_bar.clear()               # Clearing the search bar
search_bar.send_keys("pixel")       # Inputing keyword to search
search_button = driver.find_element_by_xpath('//button[@class="L0Z3Pu"]')    # Finding the xpath of search button
search_button.click()        # Clicking the search button

# Fetching urls of phones coming on 1st page
flip_urls = []
urls = driver.find_elements_by_xpath('//div[@class="_4rR01T"]')
for url in urls:
    flip_urls.append(url.get_attribute("href"))
    
    
    
#Make empty lists   
flip_dict = {}
flip_dict['Brand'] = []
flip_dict["Smartphone"] = []
flip_dict["Colour"] = []
flip_dict["RAM"] = []
flip_dict["Storage(ROM)"] = []
flip_dict["Primary Camera"] = []
flip_dict["Secondary Camera"] = []
flip_dict["Display Size"] = []
flip_dict["Display Resolution"] = []
flip_dict["Processor"] = []
flip_dict["Processor Cores"] = []
flip_dict["Battery Capacity"] = []
flip_dict["Battery Type"] = []
flip_dict["Price"] = []
flip_dict["URL"] = []

# Scraping data from each url
for url in flip_urls:
    driver.get(url)    # Saving url                                                     
    print("Scraping URL = ", url)
    flip_dict['URL'].append(url)                                                          # Loading the webpage by url
    time.sleep(2)
    
    try:
        read_more = driver.find_element_by_xpath('//button[@class="_2KpZ6l _1FH0tX"]')     # Button for expanding the specs
        read_more.click()
    except NoSuchElementException:
        print("Exception Occured. Moving to next page")
    try:
        brand = driver.find_element_by_xpath('//span[@class="B_NuCI"]')      # Extracting Brand from xpath
        flip_dict["Brand"].append(brand.text.split()[0])
    except NoSuchElementException:
        flip_dict['Brand'].append('-')
        
flip_dict['Brand']
# Out:
# <ipython-input-16-b6e72e83a71b>:11: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   login_X_button = driver.find_element_by_xpath('//button[@class="_2KpZ6l _2doB4z"]')                      # Button to close login popup
# <ipython-input-16-b6e72e83a71b>:16: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_bar = driver.find_element_by_xpath('//*[@id="container"]/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input')    # Finding the search bar using it's xpath
# <ipython-input-16-b6e72e83a71b>:19: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_button = driver.find_element_by_xpath('//button[@class="L0Z3Pu"]')    # Finding the xpath of search button
# <ipython-input-16-b6e72e83a71b>:24: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   urls = driver.find_elements_by_xpath('//div[@class="_4rR01T"]')
# []

# %%
print(len(flip_dict["Brand"]), len(flip_dict["Smartphone"]), len(flip_dict["Processor"]), len(flip_dict["Price"]), len(flip_dict['URL']))
flip_df = pd.DataFrame.from_dict(flip_dict)
flip_df
# Out:
# 0 0 0 0 0
# Empty DataFrame
# Columns: [Brand, Smartphone, Colour, RAM, Storage(ROM), Primary Camera, Secondary Camera, Display Size, Display Resolution, Processor, Processor Cores, Battery Capacity, Battery Type, Price, URL]
# Index: []

# %% [markdown]
# Q5. Write a program to scrap geospatial coordinates (latitude, longitude) of a city searched on google maps.

# %%
# Activating the chrome browser
import re
driver = webdriver.Chrome('D:/Installed Software  2/chromedriver.exe')
time.sleep(3)


# opening google maps
url = "https://www.google.co.in/maps"
driver.get(url)
time.sleep(2)


search = driver.find_element_by_id("searchboxinput")                       # locating search bar

search.send_keys("Jaipur")                                                     # entering values in search bar
button = driver.find_element_by_id("searchbox-searchbutton")               # locating search button
button.click()                                                             # clicking search button
time.sleep(3)

try:
    url_string = driver.current_url
    print("URL Extracted: ", url_string)
    lat_lng = re.findall(r'@(.*)data',url_string)
    if len(lat_lng):
        lat_lng_list = lat_lng[0].split(",")
        if len(lat_lng_list)>=2:
            lat = lat_lng_list[0]
            lng = lat_lng_list[1]
        print("Latitude = {}, Longitude = {}".format(lat, lng))

except Exception as e:
        print("Error: ", str(e))
# Out:
# <ipython-input-20-1cf2a65eb125>:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('D:/Installed Software  2/chromedriver.exe')
# <ipython-input-20-1cf2a65eb125>:13: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search = driver.find_element_by_id("searchboxinput")                       # locating search bar
# <ipython-input-20-1cf2a65eb125>:16: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   button = driver.find_element_by_id("searchbox-searchbutton")               # locating search button
# URL Extracted:  https://www.google.co.in/maps/place/Jaipur,+Rajasthan/@26.8852108,75.7905578,11z/data=!3m1!4b1!4m5!3m4!1s0x396c4adf4c57e281:0xce1c63a0cf22e09!8m2!3d26.9124336!4d75.7872709
# Latitude = 26.8852108, Longitude = 75.7905578

# %% [markdown]
# Q6. Write a program to scrap details of all the funding deals for second quarter (i.e. July 20 – September 20) from trak.in.

# %%
# Activating the chrome browser
driver = webdriver.Chrome('D:/Installed Software  2/chromedriver.exe')
time.sleep(3)

# opening trak.in
url = "https://trak.in/"
driver.get(url)
time.sleep(2)

# do click on funding deals
button = driver.find_element_by_xpath('//li[@id="menu-item-51510"]/a').get_attribute('href')
driver.get(button)

# Empty lists
fund_dict = {}
fund_dict['Date'] = []
fund_dict['Startup Name'] = []
fund_dict['Industry/Vertical'] = []
fund_dict['Sub-Vertical'] = []
fund_dict['Location'] = []
fund_dict['Investor'] = []
fund_dict['Investment Type'] = []
fund_dict['Amount(in USD)'] = []


for i in range(48,51):
    # Date
    dt = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[2]'.format(i))
    for d in dt:
        fund_dict['Date'].append(d.text)

    # Startup Name
    sn = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[3]'.format(i))
    for n in sn:
        fund_dict['Startup Name'].append(n.text)
    
    # Industry/Vertical
    ind = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[4]'.format(i))
    for n in ind:
        fund_dict['Industry/Vertical'].append(n.text)
    
    # Sub-Vertical
    sv = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[5]'.format(i))
    for s in sv:
        fund_dict['Sub-Vertical'].append(s.text)

    # Location
    loc = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[6]'.format(i))
    for l in loc:
        fund_dict['Location'].append(l.text)
    
    # Investor
    inv = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[7]'.format(i))
    for n in inv:
        fund_dict['Investor'].append(n.text)
    
    # Investment Type
    invt = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[8]'.format(i))
    for n in invt:
        fund_dict['Investment Type'].append(n.text)
    
    # Amount
    amt = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[9]'.format(i))
    for a in amt:
        fund_dict['Amount(in USD)'].append(a.text)
    
fund_df = pd.DataFrame(fund_dict)
fund_df
# Out:
# <ipython-input-21-fc0d9cba4a08>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('D:/Installed Software  2/chromedriver.exe')
# <ipython-input-21-fc0d9cba4a08>:11: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   button = driver.find_element_by_xpath('//li[@id="menu-item-51510"]/a').get_attribute('href')
# <ipython-input-21-fc0d9cba4a08>:28: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   dt = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[2]'.format(i))
# <ipython-input-21-fc0d9cba4a08>:33: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   sn = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[3]'.format(i))
# <ipython-input-21-fc0d9cba4a08>:38: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   ind = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[4]'.format(i))
# <ipython-input-21-fc0d9cba4a08>:43: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   sv = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[5]'.format(i))
# <ipython-input-21-fc0d9cba4a08>:48: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   loc = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[6]'.format(i))
# <ipython-input-21-fc0d9cba4a08>:53: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   inv = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[7]'.format(i))
# <ipython-input-21-fc0d9cba4a08>:58: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   invt = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[8]'.format(i))
# <ipython-input-21-fc0d9cba4a08>:63: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   amt = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[9]'.format(i))
#           Date               Startup Name  \
# 0   15/07/2020                   Flipkart
# 1   16/07/2020                    Vedantu
# 2   16/07/2020                       Crio
# 3   14/07/2020                    goDutch
# 4   13/07/2020                   Mystifly
# 5   09/07/2020               JetSynthesys
# 6   10/07/2020                   gigIndia
# 7   15/07/2020                  PumPumPum
# 8   14/07/2020                       FLYX
# 9   13/07/2020  Open Appliances Pvt. Ltd.
# 10  15/08/2020                     Practo
# 11  13/08/2020                    Medlife
# 12  13/08/2020                  HungerBox
# 13  04/08/2020                      Dunzo
# 14  11/08/2020                   Terra.do
# 15  12/08/2020                  Classplus
# 16  14/08/2020                       Niyo
# 17  10/08/2020                  ZestMoney
# 18  07/08/2020                FreshToHome
# 19  13/08/2020                    Eduvanz
# 20  08/09/2020                     Byju’s
# 21  12/09/2020                  mCaffeine
# 22  09/09/2020                     Qshala
# 23  02/09/2020                      Winzo
# 24  09/09/2020                Hippo Video
# 25  07/09/2020                    Melorra
# 26  07/09/2020                        1mg
# 27  31/08/2020                      mfine
# 28  31/08/2020                       Apna
# 29  03/09/2020                    Railofy
#
#                          Industry/Vertical  \
# 0                               E-commerce
# 1                                  EduTech
# 2                                  EduTech
# 3                                  FinTech
# 4                      Airfare Marketplace
# 5                 Gaming and Entertainment
# 6                              Marketplace
# 7                        Automotive Rental
# 8                               OTT Player
# 9                   Information Technology
# 10                              HealthTech
# 11                              E-commerce
# 12                                FoodTech
# 13                   Hyper-local Logistics
# 14                                 EduTech
# 15                                 EduTech
# 16                                 FinTech
# 17                                 FinTech
# 18                              E-commerce
# 19                                 FinTech
# 20                                 EduTech
# 21                           Personal Care
# 22                                 EduTech
# 23                           Online Gaming
# 24  Video Customer Experience(CX) Platform
# 25                              E-commerce
# 26                              E-commerce
# 27                              HealthTech
# 28                         Human Resources
# 29                          Transportation
#
#                                          Sub-Vertical  \
# 0                                          E-commerce
# 1                                     Online Tutoring
# 2                    Learning Platform for Developers
# 3                                      Group Payments
# 4   Ticketing, Airline Retailing, and Post-Ticketi...
# 5                            Gaming and Entertainment
# 6                           Crowd Sourcing, Freelance
# 7                           Used Car-leasing platform
# 8                            Streaming Social Network
# 9               Internet-of-Things Security Solutions
# 10                           Health care and Wellness
# 11                                    Online Pharmacy
# 12                       Online Food Delivery Service
# 13                           Online Delivery Services
# 14                  Online Climate School, E-learning
# 15                        E-learning, Online Tutoring
# 16                                 Financial Services
# 17                                 Financial Services
# 18                                      Food Delivery
# 19                                 Financial Services
# 20                                    Online Tutoring
# 21                                Skincare & Haircare
# 22                 Online Curiosity Platform for Kids
# 23                                      Online Gaming
# 24             Video Customer Experience(CX) Platform
# 25                               Online Jewelry Store
# 26                                    Online Pharmacy
# 27                      On-Demand Healthcare Services
# 28                               Recruitment Platform
# 29                       WL & RAC protection platform
#
#                                       Location  \
# 0                                    Bangalore
# 1                                    Bangalore
# 2                                    Bangalore
# 3                                       Mumbai
# 4                      Singapore and Bangalore
# 5                                         Pune
# 6                                         Pune
# 7                                      Gurgaon
# 8                           New York and Delhi
# 9                                    Bangalore
# 10                                   Bangalore
# 11                                   Bangalore
# 12                                   Bangalore
# 13                                   Bangalore
# 14                       Stanford, California,
# 15                                       Noida
# 16                                   Bangalore
# 17                                   Bangalore
# 18                                   Bangalore
# 19                                      Mumbai
# 20                                   Bangalore
# 21                                      Mumbai
# 22                                   Bangalore
# 23                                   New Delhi
# 24  Newark, Delaware, United States of Amercia
# 25                                   Bangalore
# 26                                     Gurgaon
# 27                                   Bangalore
# 28                                   Bangalore
# 29                                      Mumbai
#
#                                              Investor         Investment Type  \
# 0                                         Walmart Inc                     M&A
# 1                                   Coatue Management                Series D
# 2                                         021 Capital            pre-Series A
# 3   Matrix India,Y Combinator, Global Founders Cap...                    Seed
# 4                                    Recruit Co. Ltd.            pre-Series B
# 5            Adar Poonawalla and Kris Gopalakrishnan.  Venture-Series Unknown
# 6        Incubate Fund India and Beyond Next Ventures            pre-Series A
# 7                            Early Adapters Syndicate                    Seed
# 8               Raj Mishra, founder of AIT Global Inc                pre-Seed
# 9                              Unicorn India Ventures  Venture-Series Unknown
# 10                                        A1A Company                Series F
# 11         Prasid Uno Family Trust and SC Credit Fund
# 12  One97, Sabre Partners Trust, Pratithi Investme...               Series D1
# 13                                   Existing Backers             In Progress
# 14  Stanford Angels and Entrepreneurs (India), BEE...                    Seed
# 15                                        Falcon Edge             In Progress
# 16                                Niyo Solutions Inc.
# 17                            Primrose Hills Ventures
# 18                                     Ascent Capital                 Venture
# 19                              Sequoia India, Unitus                Series A
# 20  Silver Lake, Tiger Global, General Atlantic an...          Private Equity
# 21  Amicus Capital Private Equity I LLP, Amicus Ca...                Series B
# 22                                 Rainmatter Capital                   Angel
# 23  Kalaari Capital Partners, IndigoEdge Managemen...                Series B
# 24  Alpha Wave Incubation, Exfinity Venture Partne...                Series A
# 25                         Shadow Holdings, Lightbox.          Debt Financing
# 26         Gaja Capital, Tata Capital, Partners Group             In Progress
# 27                                   Caretech Pte Inc                Series B
# 28         Lightspeed India and Sequoia Capital India                Series A
# 29                                  Chiratae Ventures                    Seed
#
#      Amount(in USD)
# 0     1,200,000,000
# 1       100,000,000
# 2           934,160
# 3         1,700,000
# 4         3,300,000
# 5           400,000
# 6           974,200
# 7           292,800
# 8           200,000
# 9           500,000
# 10       32,000,000
# 11       23,000,000
# 12        1,560,000
# 13       30,000,000
# 14        1,400,000
# 15  upto 15,000,000
# 16        6,000,000
# 17       10,670,000
# 18       16,200,000
# 19        5,000,000
# 20      500,000,000
# 21        3,000,000
# 22          370,000
# 23       15,500,000
# 24        4,500,000
# 25   upto 8,900,000
# 26      100,000,000
# 27        5,400,000
# 28        8,000,000
# 29          950,000

# %% [markdown]
# Q7. Write a program to scrap all the available details of best gaming laptops from digit.in.

# %%
# Activating the chrome browser
driver = webdriver.Chrome('D:/Installed Software  2/chromedriver.exe')
time.sleep(3)

# opening www.digit.in
url = "https://www.digit.in/"
driver.get(url)
time.sleep(2)

#clicking on top 10 option 
top_10=driver.find_element_by_xpath("/html/body/div[1]/div/div[4]/ul/li[4]/a")
top_10.click()
# Out:
# <ipython-input-34-0f3a0f68cb7f>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('D:/Installed Software  2/chromedriver.exe')
# <ipython-input-34-0f3a0f68cb7f>:11: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   top_10=driver.find_element_by_xpath("/html/body/div[1]/div/div[4]/ul/li[4]/a")

# %%
time.sleep(2)
#clicking on laptops option
laptops=driver.find_element_by_xpath("/html/body/div[3]/div/div/div[2]/div[5]/div[1]/div/button[2]")
laptops.click()

time.sleep(2)
#best gaming laptops link
best_gaming=driver.find_element_by_xpath("//div[@id='laptops']//div[3]//a")
driver.get(best_gaming.get_attribute('href'))

#intialising lists
name = []
Price = []
OS = []
display = []
processor = []
HDD = []
RAM = []
weight = []
dimension = []
GPU = []

time.sleep(1)
#scraping names
names=driver.find_elements_by_xpath("//div[@class='right-container']/div/a/h3")
for i in names:
    name.append(i.text)

time.sleep(1)
#scraping operating system
os=driver.find_elements_by_xpath("//div[@class='product-detail']/div/ul/li[1]/div/div")
for i in os:
    OS.append(i.text)

time.sleep(1)
#scraping display
displays=driver.find_elements_by_xpath("//div[@class='product-detail']/div/ul/li[2]/div/div")
for i in displays:
    display.append(i.text)

time.sleep(1)
#scraping processor
processors=driver.find_elements_by_xpath("//div[@class='product-detail']/div/ul/li[3]/div/div")
for i in processors:
    processor.append(i.text)

time.sleep(1)
# scraping memory
memories=driver.find_elements_by_xpath("//div[@class='Spcs-details'][1]/table/tbody/tr[6]/td[3]")# extrat HDD and RAM form xpath
for i in memories:
    HDD.append(i.text.split("/")[0])
    RAM.append(i.text.split("/")[1])

time.sleep(1)
# scraping weight
weights=driver.find_elements_by_xpath("//div[@class='Spcs-details'][1]/table/tbody/tr[7]/td[3]")# extrat weight form xpath
for i in weights:
    weight.append(i.text)

time.sleep(1)
# scraping dimension
dimension=[]
dimensions=driver.find_elements_by_xpath("//div[@class='Spcs-details'][1]/table/tbody/tr[8]/td[3]") 
for i in dimensions:
    dimension.append(i.text)

time.sleep(1)
# scraping graphical processor
GPUs=driver.find_elements_by_xpath("//div[@class='Spcs-details'][1]/table/tbody/tr[9]/td[3]") 
for i in GPUs:
    GPU.append(i.text)

time.sleep(1)

#scraping price
price=driver.find_elements_by_xpath("//table[@id='summtable']//tr//td[3]")
for i in price:
    Price.append(i.text)

#Make data frame

a={"Name":name,"price":Price,"OS":OS,"Display":display,"HDD":HDD,"RAM":RAM,"processor":processor,"weight":weight,"Dimension":dimension,"Graphical processor":GPU}
df = pd.DataFrame.from_dict(a, orient='index')
df = df.transpose()
df
# Out:
# <ipython-input-35-4d906e69b5f4>:3: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   laptops=driver.find_element_by_xpath("/html/body/div[3]/div/div/div[2]/div[5]/div[1]/div/button[2]")
# <ipython-input-35-4d906e69b5f4>:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   best_gaming=driver.find_element_by_xpath("//div[@id='laptops']//div[3]//a")
# <ipython-input-35-4d906e69b5f4>:25: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   names=driver.find_elements_by_xpath("//div[@class='right-container']/div/a/h3")
# <ipython-input-35-4d906e69b5f4>:31: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   os=driver.find_elements_by_xpath("//div[@class='product-detail']/div/ul/li[1]/div/div")
# <ipython-input-35-4d906e69b5f4>:37: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   displays=driver.find_elements_by_xpath("//div[@class='product-detail']/div/ul/li[2]/div/div")
# <ipython-input-35-4d906e69b5f4>:43: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   processors=driver.find_elements_by_xpath("//div[@class='product-detail']/div/ul/li[3]/div/div")
# <ipython-input-35-4d906e69b5f4>:49: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   memories=driver.find_elements_by_xpath("//div[@class='Spcs-details'][1]/table/tbody/tr[6]/td[3]")# extrat HDD and RAM form xpath
# <ipython-input-35-4d906e69b5f4>:56: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   weights=driver.find_elements_by_xpath("//div[@class='Spcs-details'][1]/table/tbody/tr[7]/td[3]")# extrat weight form xpath
# <ipython-input-35-4d906e69b5f4>:63: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   dimensions=driver.find_elements_by_xpath("//div[@class='Spcs-details'][1]/table/tbody/tr[8]/td[3]")
# <ipython-input-35-4d906e69b5f4>:69: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   GPUs=driver.find_elements_by_xpath("//div[@class='Spcs-details'][1]/table/tbody/tr[9]/td[3]")
# <ipython-input-35-4d906e69b5f4>:76: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   price=driver.find_elements_by_xpath("//table[@id='summtable']//tr//td[3]")
#                                             Name      price               OS  \
# 0                    ACER NITRO 5 RYZEN 9 (2021)  ₹ 129,990       WINDOWS 10
# 1  MSI STEALTH 15M 11TH GEN CORE I7-11375H (2021  ₹ 134,990       WINDOWS 10
# 2   ASUS ROG STRIX SCAR 15 RYZEN 9-5900HX (2021)  ₹ 268,990       WINDOWS 10
# 3                          ALIENWARE AREA 51M R2  ₹ 342,989  WINDOWS 10 HOME
# 4                               ALIENWARE M15 R3  ₹ 319,990  WINDOWS 10 HOME
# 5                         ASUS ROG STRIX SCAR 15  ₹ 215,990  WINDOWS 10 HOME
# 6                          ASUS ROG ZEPHYRUS G14  ₹ 164,990  WINDOWS 10 HOME
# 7                               LENOVO LEGION 5I   ₹ 76,988   WINDOWS 10 PRO
# 8                       ASUS ROG ZEPHYRUS DUO 15  ₹ 185,000       WINDOWS 10
# 9                           ACER ASPIRE 7 GAMING   ₹ 58,289  WINDOWS 10 HOME
#
#                Display         HDD           RAM processor weight  \
# 0  15.6" (1920 X 1080)    1 TB HDD  16 GBGB DDR4      None    2.4
# 1  15.6" (1920 X 1080)    1 TB SSD  16 GBGB DDR4      None    1.7
# 2  15.6" (2560 X 1440)    2 TB SSD  32 GBGB DDR4      None   2.30
# 3  17.3" (1920 X 1080)    1 TB SSD  16 GBGB DDR4      None    4.1
# 4  15.6" (3840 X 2160)    1 TB SSD  16 GBGB DDR4      None     NA
# 5  15.6" (1920 X 1080)    1 TB SSD  16 GBGB DDR4      None   2.30
# 6    14" (1920 X 1080)    1 TB SSD  16 GBGB DDR4      None   1.65
# 7  15.6" (1920 X 1080)    1 TB SSD  16 GBGB DDR4      None    2.3
# 8  15.6" (3840 X 1100)  512 GB SSD   4 GBGB DDR4      None    2.4
# 9  15.6" (1920 X 1080)  512 GB SSD   8 GBGB DDR4      None   2.15
#
#                  Dimension            Graphical processor
# 0       363.4 x 255 x 23.9        NVIDIA GeForce RTX 3070
# 1      358.3 x 248 x 16.15        NVIDIA GeForce RTX 3060
# 2         354 x 259 x 22.6        NVIDIA GeForce RTX 3080
# 3   27.65 x 402.6 x 319.14        Intel® UHD Graphics 630
# 4                       NA                             NA
# 5       35.4 x 25.9 x 2.26      NVIDIA® GeForce RTX™ 3070
# 6        32.5 x 22.1 x 1.8        NVIDIA GeForce RTX 2060
# 7  363.06 x 259.61 x 23.57  NVIDIA® GeForce® GTX 1650 4GB
# 8  268.30 x 360.00 x 20.90  NVIDIA GeForce RTX 2070 Max-Q
# 9       2.29 x 36.3 x 25.4      NVIDIA® GeForce® GTX 1650

# %% [markdown]
# Q8. Write a python program to scrape the details for all billionaires from www.forbes.com. Details to be scrapped: “Rank”, “Name”, “Net worth”, “Age”, “Citizenship”, “Source”, “Industry”.

# %%
driver = webdriver.Chrome('D:/Installed Software  2/chromedriver.exe')
page_url = 'https://www.forbes.com/billionaires/'
driver.get(page_url)
# Out:
# <ipython-input-9-62107f1f229b>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('D:/Installed Software  2/chromedriver.exe')

# %%
rank = []
Pname = []
NetWorth = []
Age = []
Citizenship = []
Source = []
Industry = []

for page in range(0,13):
         
    Rank = driver.find_elements_by_xpath("//div[@class = 'rank']")
    for i in Rank:
        txt = i.text
        rank.append(txt)

    name = driver.find_elements_by_xpath("//div[@class = 'personName']")
    for i in name:
        Pname.append(i.text)

    nworth = driver.find_elements_by_xpath("//div[@class = 'netWorth']")
    for i in nworth:
        NetWorth.append(i.text)

    age = driver.find_elements_by_xpath("//div[@class = 'age']")
    for i in age:
        Age.append(i.text)

    citizenship = driver.find_elements_by_xpath("//div[@class = 'countryOfCitizenship']")
    for i in citizenship:
        Citizenship.append(i.text)

    source = driver.find_elements_by_xpath("//div[@class = 'source-column']")
    for i in source:
        Source.append(i.text)

    industry = driver.find_elements_by_xpath("//div[@class = 'category']")
    for i in industry:
        Industry.append(i.text)
        
    next_page = driver.find_element_by_xpath("//button[@class = 'pagination-btn pagination-btn--next ']")
    next_page.click()

df = pd.DataFrame({'Rank':rank,
                   'Name':Pname,
                   'Net Worth':NetWorth,
                   'Age':Age, 
                   'Citizenship':Citizenship, 
                   'Source':Source, 
                   'Industry':Industry})
df
# Out:
# <ipython-input-10-6f5fb189b1ca>:11: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   Rank = driver.find_elements_by_xpath("//div[@class = 'rank']")
# <ipython-input-10-6f5fb189b1ca>:16: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   name = driver.find_elements_by_xpath("//div[@class = 'personName']")
# <ipython-input-10-6f5fb189b1ca>:20: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   nworth = driver.find_elements_by_xpath("//div[@class = 'netWorth']")
# <ipython-input-10-6f5fb189b1ca>:24: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   age = driver.find_elements_by_xpath("//div[@class = 'age']")
# <ipython-input-10-6f5fb189b1ca>:28: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   citizenship = driver.find_elements_by_xpath("//div[@class = 'countryOfCitizenship']")
# <ipython-input-10-6f5fb189b1ca>:32: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   source = driver.find_elements_by_xpath("//div[@class = 'source-column']")
# <ipython-input-10-6f5fb189b1ca>:36: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   industry = driver.find_elements_by_xpath("//div[@class = 'category']")
# <ipython-input-10-6f5fb189b1ca>:40: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   next_page = driver.find_element_by_xpath("//button[@class = 'pagination-btn pagination-btn--next ']")
#        Rank                      Name Net Worth Age    Citizenship  \
# 0        1.                Jeff Bezos    $177 B  57  United States
# 1        2.                 Elon Musk    $151 B  49  United States
# 2        3.  Bernard Arnault & family    $150 B  72         France
# 3        4.                Bill Gates    $124 B  65  United States
# 4        5.           Mark Zuckerberg     $97 B  36  United States
# ...     ...                       ...       ...  ..            ...
# 2595  2524.            Low Tuck Kwong    $1.1 B  72      Indonesia
# 2596  2524.                Lu Weiding    $1.1 B  50          China
# 2597  2524.              Lv Yongxiang    $1.1 B  71          China
# 2598  2524.   Cargill MacMillan, III.    $1.1 B  61  United States
# 2599  2524.            John MacMillan    $1.1 B  71  United States
#
#                  Source          Industry
# 0                Amazon        Technology
# 1         Tesla, SpaceX        Automotive
# 2                  LVMH  Fashion & Retail
# 3             Microsoft        Technology
# 4              Facebook        Technology
# ...                 ...               ...
# 2595               coal            Energy
# 2596        diversified       Diversified
# 2597  magnetic switches     Manufacturing
# 2598            Cargill   Food & Beverage
# 2599            Cargill   Food & Beverage
#
# [2600 rows x 7 columns]

# %% [markdown]
# Q9.Write a program to extract at least 500 Comments, Comment upvote and time when comment was posted from any YouTube Video.

# %%
# Activating the chrome browser
driver = webdriver.Chrome('D:/Installed Software  2/chromedriver.exe')
time.sleep(3)

# Opening the youtube.com
url = "https://www.youtube.com/"
driver.get(url)
time.sleep(2)

#finding element for search bar
search_bar = driver.find_element_by_xpath("//div[@class='ytd-searchbox-spt']/input")
search_bar.send_keys("Shape of You")  #entering Video name
time.sleep(1)

#clicking on search button
search_btn = driver.find_element_by_id("search-icon-legacy")  
search_btn.click()
time.sleep(1)
# Out:
# <ipython-input-62-850c3b282183>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('D:/Installed Software  2/chromedriver.exe')
# <ipython-input-62-850c3b282183>:11: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_bar = driver.find_element_by_xpath("//div[@class='ytd-searchbox-spt']/input")
# <ipython-input-62-850c3b282183>:16: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_btn = driver.find_element_by_id("search-icon-legacy")

# %%
#clicking on first video
link_click = driver.find_element_by_xpath("//yt-formatted-string[@class ='style-scope ytd-video-renderer']")
link_click.click()
# 1000 time we scroll down by 10000 in order to generate more Comments
for _ in range(1000):
    driver.execute_script("window.scrollBy(0,10000)")
#make empty lists
comments = []
comment_time = []
Time = []
Likes = []
No_of_Likes = []

#scrape comments
cm = driver.find_elements_by_id("content-text")
for i in cm:
    if i.text is None:
        comments.append("--")
    else:
        comments.append(i.text)
time.sleep(5)


# scrape time when comment was posted
tm = driver.find_elements_by_xpath("//a[contains(text(),'ago')]")
for i in tm:
    Time.append(i.text)

for i in range(0,len(Time),2):
    comment_time.append(Time[i])
time.sleep(5)
    
# scrape the comment likes
like = driver.find_elements_by_xpath("//span[@class='style-scope ytd-comment-action-buttons-renderer']")
for i in like:
    Likes.append(i.text)
    
for i in range(1,len(Likes),2):
    No_of_Likes.append(Likes[i])
    
    
time.sleep(2)
#creating dataframe
a = {'Comments':comments,'Time':comment_time,'Likes':No_of_Likes}
df = pd.DataFrame.from_dict(a, orient='index')
df = df.transpose()
df
# Out:
# <ipython-input-63-24d0dd84b02a>:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   link_click = driver.find_element_by_xpath("//yt-formatted-string[@class ='style-scope ytd-video-renderer']")
# <ipython-input-63-24d0dd84b02a>:15: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   cm = driver.find_elements_by_id("content-text")
# <ipython-input-63-24d0dd84b02a>:25: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   tm = driver.find_elements_by_xpath("//a[contains(text(),'ago')]")
# <ipython-input-63-24d0dd84b02a>:34: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   like = driver.find_elements_by_xpath("//span[@class='style-scope ytd-comment-action-buttons-renderer']")

# %% [markdown]
# Q10. Write a python program to scrape a data for all available Hostels from https://www.hostelworld.com/ in “London” location. You have to scrape hostel name, distance from city centre, ratings, total reviews, overall reviews, privates from price, dorms from price, facilities and property description

# %%
# Activating the chrome browser
driver = webdriver.Chrome('D:/Installed Software  2/chromedriver.exe')
time.sleep(3)

# Opening the homepage of hostelworld.com
url = "https://www.hostelworld.com/"
driver.get(url)
#locating the location search bar
search_loc = driver.find_element_by_xpath("//input[@class='location-text']")
# write Lonodn in search bar
search_loc.send_keys("London")
time.sleep(2)

#select london
london = driver.find_element_by_xpath("//button[@class='button primary large']")
london.click()
time.sleep(2)

london_Hostel = driver.find_element_by_xpath("//*[@id='__layout']/div/div[1]/div[5]/section/div/div[1]/a")
london_Hostel.click()
# Out:
# <ipython-input-60-0cdb2f71917f>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('D:/Installed Software  2/chromedriver.exe')
# <ipython-input-60-0cdb2f71917f>:9: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_loc = driver.find_element_by_xpath("//input[@class='location-text']")
# <ipython-input-60-0cdb2f71917f>:15: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   london = driver.find_element_by_xpath("//button[@class='button primary large']")
# <ipython-input-60-0cdb2f71917f>:19: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   london_Hostel = driver.find_element_by_xpath("//*[@id='__layout']/div/div[1]/div[5]/section/div/div[1]/a")

# %%
while(True):
    
    # Hostel name
    names = driver.find_elements_by_xpath('//h2[@class="title title-6"]')
    for name in names:
        Hostel_Name.append(name.text)
    time.sleep(2)
        
    # Distance from city centre
    dis = driver.find_elements_by_xpath('//span[@class="description"]')
    for d in dis:
        Distance.append(d.text)
    time.sleep(2)
        
    # Overall Review    
    review = driver.find_elements_by_xpath('//div[@class="keyword"]//span')
    for r in review:
        overall_review.append(r.text)
    time.sleep(2)
    
    # Total No of reviews     
    t_review = driver.find_elements_by_xpath('//div[@class="reviews"]')
    for tr in t_review:
        total_reviews.append(tr.text)
    time.sleep(2)
    
    # facilities
    service = driver.find_elements_by_xpath('//div[@class="facilities-label facilities"]')
    for s in service:
        facilities.append(s.text)
    time.sleep(2)
    
    # Prices    
    prices = driver.find_elements_by_xpath('//div[@class="price-col"]')
    for p in prices:
        price.append(p.text)
    time.sleep(2)    
        
    try:
        next_button = driver.find_element_by_xpath('//div[@class="pagination-item pagination-next"]')
        next_button.click()
    except:
        break
        
time.sleep(4)        
        
# Separate  Privates_From price  and  Dorms_From price
Privates_From = []
for i in range(0,len(price),2):
    Privates_From.append(price[i])
time.sleep(2)

Dorms_From = []
for i in range(1,len(price),2):
    Dorms_From.append(price[i])           
# scrape Hostels URL
hostel_url = []

while(True):
    urls = driver.find_elements_by_xpath('//h2[@class="title title-6"]//a')
    for url in urls:
        hostel_url.append(url.get_attribute("href"))
    time.sleep(2)    
        
    try:
        next_button = driver.find_element_by_xpath('//div[@class="pagination-item pagination-next"]')
        next_button.click()
    except:
        break


        
Rate = []
for page in hostel_url:
    driver.get(page)
    
    # Rating
    try:
        ratings = driver.find_element_by_xpath('/html/body/div[1]/div/div/div[1]/section/div[6]/div/div[1]/div[1]/div[1]')
        Rate.append(ratings.text)
    except NoSuchElementException:
        Rate.append("No Rating")  
    time.sleep(2)
    
    
    # Property Description
    try:
        pd = driver.find_element_by_xpath('/html/body/div[1]/div/div/div[1]/section/div[6]/div/div[2]/div[2]/div/div[2]')
        property_description.append(pd.text)
    except NoSuchElementException:
        property_description.append("No Description")  

    
time.sleep(2)        
# remove extra data from Rating     
all_text = []
for i in Rate:
    all_text.append(i.split())
time.sleep(2)

for i in all_text:
    Rating.append(i[0]) 
#creating dataframe
df = pd.DataFrame({'Hostel Name':Hostel_Name,
                'Distance from city centre':Distance,
                'Overall Review':overall_review[3:],
                'Total Reviews':total_reviews,
                'Facilities':facilities,
                'Privates From Price':Privates_From,
                'Dorms From Price':Dorms_From,
                'Rating':Rating,
                'Property Description':property_description})
df
# Out:
# <ipython-input-61-5508c9627db0>:4: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   names = driver.find_elements_by_xpath('//h2[@class="title title-6"]')
# <ipython-input-61-5508c9627db0>:10: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   dis = driver.find_elements_by_xpath('//span[@class="description"]')
# <ipython-input-61-5508c9627db0>:16: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   review = driver.find_elements_by_xpath('//div[@class="keyword"]//span')
# <ipython-input-61-5508c9627db0>:22: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   t_review = driver.find_elements_by_xpath('//div[@class="reviews"]')
# <ipython-input-61-5508c9627db0>:28: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   service = driver.find_elements_by_xpath('//div[@class="facilities-label facilities"]')
# <ipython-input-61-5508c9627db0>:34: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   prices = driver.find_elements_by_xpath('//div[@class="price-col"]')
# <ipython-input-61-5508c9627db0>:40: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   next_button = driver.find_element_by_xpath('//div[@class="pagination-item pagination-next"]')
# <ipython-input-61-5508c9627db0>:60: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   urls = driver.find_elements_by_xpath('//h2[@class="title title-6"]//a')
# <ipython-input-61-5508c9627db0>:66: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   next_button = driver.find_element_by_xpath('//div[@class="pagination-item pagination-next"]')
# Empty DataFrame
# Columns: [Hostel Name, Distance from city centre, Overall Review, Total Reviews, Facilities, Privates From Price, Dorms From Price, Rating, Property Description]
# Index: []
